# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_list = []

for i in range(9):
    csv_list.append(pd.read_csv("../album_data_23/" + str(2015+i) + "_23countries_album.csv"))

# %%
csv_list
# Out:
# [          기간    국가          HS코드          품목명   수출 중량  수출 금액   수입 중량  수입 금액  \
#  0         총계   NaN           NaN          NaN  746634  28864  122191   5312
#  1    2015-01  네덜란드  8.523491e+09  음성만을 재생하는 것       0      0     154      6
#  2    2015-01    대만  8.523491e+09  음성만을 재생하는 것    4865    121      11      0
#  3    2015-01    독일  8.523491e+09  음성만을 재생하는 것      60      3    4821    175
#  4    2015-01    미국  8.523491e+09  음성만을 재생하는 것    1127     34     999     65
#  ..       ...   ...           ...          ...     ...    ...     ...    ...
#  196  2015-12   캐나다  8.523491e+09  음성만을 재생하는 것       0      0      12      0
#  197  2015-12    태국  8.523491e+09  음성만을 재생하는 것     694     22       0      0
#  198  2015-12   프랑스  8.523491e+09  음성만을 재생하는 것    1102     27      55      3
#  199  2015-12    호주  8.523491e+09  음성만을 재생하는 것       0      0       3      0
#  200  2015-12    홍콩  8.523491e+09  음성만을 재생하는 것    3549    127      47      3
#
#        무역수지
#  0    23552
#  1       -6
#  2      121
#  3     -172
#  4      -32
#  ..     ...
#  196      0
#  197     22
#  198     24
#  199      0
#  200    123
#
#  [201 rows x 9 columns],
#            기간    국가          HS코드          품목명    수출 중량  수출 금액   수입 중량  수입 금액  \
#  0         총계   NaN           NaN          NaN  1048329  29444  113738   4516
#  1    2016-01  네덜란드  8.523491e+09  음성만을 재생하는 것        0      0     141      5
#  2    2016-01    대만  8.523491e+09  음성만을 재생하는 것     4265    117     287     13
#  3    2016-01    독일  8.523491e+09  음성만을 재생하는 것      610     16    4294    131
#  4    2016-01    미국  8.523491e+09  음성만을 재생하는 것     1215     23     937     44
#  ..       ...   ...           ...          ...      ...    ...     ...    ...
#  209  2016-12   캐나다  8.523491e+09  음성만을 재생하는 것        0      0      26      0
#  210  2016-12    태국  8.523491e+09  음성만을 재생하는 것      299      6       1      0
#  211  2016-12   프랑스  8.523491e+09  음성만을 재생하는 것      351      6      46      4
#  212  2016-12    호주  8.523491e+09  음성만을 재생하는 것       34      1       0      0
#  213  2016-12    홍콩  8.523491e+09  음성만을 재생하는 것     6555    150      22      0
#
#        무역수지
#  0    24928
#  1       -5
#  2      104
#  3     -115
#  4      -21
#  ..     ...
#  209      0
#  210      5
#  211      3
#  212      1
#  213    149
#
#  [214 rows x 9 columns],
#            기간      국가          HS코드          품목명    수출 중량  수출 금액   수입 중량  \
#  0         총계     NaN           NaN          NaN  1375541  43501  112607
#  1    2017-01    네덜란드  8.523491e+09  음성만을 재생하는 것        2      0     163
#  2    2017-01      대만  8.523491e+09  음성만을 재생하는 것     5222    174     460
#  3    2017-01      독일  8.523491e+09  음성만을 재생하는 것     1354     28    2993
#  4    2017-01  러시아 연방  8.523491e+09  음성만을 재생하는 것        0      0       0
#  ..       ...     ...           ...          ...      ...    ...     ...
#  236  2017-12     캐나다  8.523491e+09  음성만을 재생하는 것        2      0       2
#  237  2017-12      태국  8.523491e+09  음성만을 재생하는 것     2907     48       0
#  238  2017-12     프랑스  8.523491e+09  음성만을 재생하는 것        3      0     351
#  239  2017-12      호주  8.523491e+09  음성만을 재생하는 것       53      1       0
#  240  2017-12      홍콩  8.523491e+09  음성만을 재생하는 것     9842    251     218
#
#       수입 금액   무역수지
#  0     4853  38648
#  1        6     -6
#  2       22    152
#  3       91    -64
#  4        0      0
#  ..     ...    ...
#  236      0      0
#  237      0     48
#  238     14    -14
#  239      0      1
#  240      4    247
#
#  [241 rows x 9 columns],
#            기간    국가          HS코드          품목명    수출 중량  수출 금액  수입 중량  수입 금액  \
#  0         총계   NaN           NaN          NaN  2220272  63273  94646   4175
#  1    2018-01  네덜란드  8.523491e+09  음성만을 재생하는 것     1982     61     29      1
#  2    2018-01    대만  8.523491e+09  음성만을 재생하는 것     7483    212    245      9
#  3    2018-01    독일  8.523491e+09  음성만을 재생하는 것     1851     54    779     46
#  4    2018-01   멕시코  8.523491e+09  음성만을 재생하는 것       40      0     25      1
#  ..       ...   ...           ...          ...      ...    ...    ...    ...
#  253  2018-12   캐나다  8.523491e+09  음성만을 재생하는 것      351      2     12      0
#  254  2018-12    태국  8.523491e+09  음성만을 재생하는 것     1184     32      0      0
#  255  2018-12   프랑스  8.523491e+09  음성만을 재생하는 것        1      0     56      3
#  256  2018-12    호주  8.523491e+09  음성만을 재생하는 것      809      9      0      0
#  257  2018-12    홍콩  8.523491e+09  음성만을 재생하는 것     5868    141      3      0
#
#        무역수지
#  0    59098
#  1       60
#  2      203
#  3        8
#  4        0
#  ..     ...
#  253      1
#  254     32
#  255     -3
#  256      9
#  257    141
#
#  [258 rows x 9 columns],
#            기간      국가          HS코드          품목명    수출 중량  수출 금액   수입 중량  \
#  0         총계     NaN           NaN          NaN  2801247  72890  122854
#  1    2019-01    네덜란드  8.523491e+09  음성만을 재생하는 것     6811    214     148
#  2    2019-01      대만  8.523491e+09  음성만을 재생하는 것    11179    324       0
#  3    2019-01      독일  8.523491e+09  음성만을 재생하는 것     1762     36    1784
#  4    2019-01  러시아 연방  8.523491e+09  음성만을 재생하는 것       50      2       0
#  ..       ...     ...           ...          ...      ...    ...     ...
#  267  2019-12     캐나다  8.523491e+09  음성만을 재생하는 것     1330     10      54
#  268  2019-12      태국  8.523491e+09  음성만을 재생하는 것     4314     55       0
#  269  2019-12     프랑스  8.523491e+09  음성만을 재생하는 것     6755    146     197
#  270  2019-12      호주  8.523491e+09  음성만을 재생하는 것     2719     61       2
#  271  2019-12      홍콩  8.523491e+09  음성만을 재생하는 것     6500    164       5
#
#       수입 금액   무역수지
#  0     5230  67660
#  1        8    205
#  2        0    324
#  3       65    -29
#  4        0      2
#  ..     ...    ...
#  267     32    -22
#  268      0     55
#  269      9    137
#  270      0     61
#  271      0    164
#
#  [272 rows x 9 columns],
#            기간      국가          HS코드          품목명    수출 중량   수출 금액   수입 중량  \
#  0         총계     NaN           NaN          NaN  5530259  132521  145856
#  1    2020-01    네덜란드  8.523491e+09  음성만을 재생하는 것     7443     183      18
#  2    2020-01      대만  8.523491e+09  음성만을 재생하는 것    12633     346      20
#  3    2020-01      독일  8.523491e+09  음성만을 재생하는 것      750      15    1105
#  4    2020-01  러시아 연방  8.523491e+09  음성만을 재생하는 것      220       6       0
#  ..       ...     ...           ...          ...      ...     ...     ...
#  270  2020-12     캐나다  8.523491e+09  음성만을 재생하는 것     3119      48      26
#  271  2020-12      태국  8.523491e+09  음성만을 재생하는 것    11910     275      55
#  272  2020-12     프랑스  8.523491e+09  음성만을 재생하는 것    15346     372     196
#  273  2020-12      호주  8.523491e+09  음성만을 재생하는 것     4162      91       2
#  274  2020-12      홍콩  8.523491e+09  음성만을 재생하는 것    14033     382     100
#
#       수입 금액    무역수지
#  0     4075  128446
#  1        2     181
#  2        0     346
#  3       33     -18
#  4        0       6
#  ..     ...     ...
#  270      1      47
#  271      4     270
#  272     11     361
#  273      0      91
#  274      5     377
#
#  [275 rows x 9 columns],
#            기간      국가          HS코드          품목명    수출 중량   수출 금액   수입 중량  \
#  0         총계     NaN           NaN          NaN  7647135  212222  182855
#  1    2021-01    네덜란드  8.523491e+09  음성만을 재생하는 것     6320     146      87
#  2    2021-01      대만  8.523491e+09  음성만을 재생하는 것    13247     409      28
#  3    2021-01      독일  8.523491e+09  음성만을 재생하는 것     3033      70    2570
#  4    2021-01  러시아 연방  8.523491e+09  음성만을 재생하는 것      547      14       1
#  ..       ...     ...           ...          ...      ...     ...     ...
#  271  2021-12     캐나다  8.523491e+09  음성만을 재생하는 것     2789      88      38
#  272  2021-12      태국  8.523491e+09  음성만을 재생하는 것    18888     560      17
#  273  2021-12     프랑스  8.523491e+09  음성만을 재생하는 것    14650     350     327
#  274  2021-12      호주  8.523491e+09  음성만을 재생하는 것     3592      92       1
#  275  2021-12      홍콩  8.523491e+09  음성만을 재생하는 것    10252     263      67
#
#       수입 금액    무역수지
#  0     7908  204314
#  1        6     140
#  2        2     407
#  3      135     -64
#  4        0      14
#  ..     ...     ...
#  271      1      87
#  272      0     560
#  273      7     344
#  274      0      92
#  275      6     257
#
#  [276 rows x 9 columns],
#            기간      국가          HS코드         품목명    수출 중량   수출 금액  수입 중량  수입 금액  \
#  0         총계     NaN           NaN         NaN  9400954  223209  97384   3918
#  1    2022-01    네덜란드  8.523491e+09  음성만을 기록한 것    14305     276     87      6
#  2    2022-01      대만  8.523491e+09  음성만을 기록한 것    11127     256    493      3
#  3    2022-01      독일  8.523491e+09  음성만을 기록한 것    10836     248   4388    178
#  4    2022-01  러시아 연방  8.523491e+09  음성만을 기록한 것     2444      73     13      1
#  ..       ...     ...           ...         ...      ...     ...    ...    ...
#  272  2022-12     캐나다  8.523491e+09  음성만을 기록한 것    12643     348      1      0
#  273  2022-12      태국  8.523491e+09  음성만을 기록한 것    14421     161      0      0
#  274  2022-12     프랑스  8.523491e+09  음성만을 기록한 것     8932     243      4      0
#  275  2022-12      호주  8.523491e+09  음성만을 기록한 것     5870     169      5      0
#  276  2022-12      홍콩  8.523491e+09  음성만을 기록한 것    18071     507      0      0
#
#         무역수지
#  0    219291
#  1       270
#  2       253
#  3        70
#  4        71
#  ..      ...
#  272     348
#  273     161
#  274     242
#  275     169
#  276     507
#
#  [277 rows x 9 columns],
#            기간      국가          HS코드         품목명     수출 중량   수출 금액   수입 중량  \
#  0         총계     NaN           NaN         NaN  11828358  280884  172616
#  1    2023-01    네덜란드  8.523491e+09  음성만을 기록한 것     18627     390     193
#  2    2023-01      대만  8.523491e+09  음성만을 기록한 것     24615     874       0
#  3    2023-01      독일  8.523491e+09  음성만을 기록한 것     18404     481    2359
#  4    2023-01  러시아 연방  8.523491e+09  음성만을 기록한 것      7599     162       0
#  ..       ...     ...           ...         ...       ...     ...     ...
#  272  2023-12     캐나다  8.523491e+09  음성만을 기록한 것     10140     315      13
#  273  2023-12      태국  8.523491e+09  음성만을 기록한 것      4774      78       1
#  274  2023-12     프랑스  8.523491e+09  음성만을 기록한 것      8018     284      31
#  275  2023-12      호주  8.523491e+09  음성만을 기록한 것      3821     138       0
#  276  2023-12      홍콩  8.523491e+09  음성만을 기록한 것     10906     362      12
#
#       수입 금액    무역수지
#  0     5429  275455
#  1       12     379
#  2        0     874
#  3       89     391
#  4        0     162
#  ..     ...     ...
#  272      1     315
#  273      0      78
#  274      2     283
#  275      0     138
#  276      2     360
#
#  [277 rows x 9 columns]]

# %%
csv_list[0]
# Out:
#           기간    국가          HS코드          품목명   수출 중량  수출 금액   수입 중량  수입 금액  \
# 0         총계   NaN           NaN          NaN  746634  28864  122191   5312
# 1    2015-01  네덜란드  8.523491e+09  음성만을 재생하는 것       0      0     154      6
# 2    2015-01    대만  8.523491e+09  음성만을 재생하는 것    4865    121      11      0
# 3    2015-01    독일  8.523491e+09  음성만을 재생하는 것      60      3    4821    175
# 4    2015-01    미국  8.523491e+09  음성만을 재생하는 것    1127     34     999     65
# ..       ...   ...           ...          ...     ...    ...     ...    ...
# 196  2015-12   캐나다  8.523491e+09  음성만을 재생하는 것       0      0      12      0
# 197  2015-12    태국  8.523491e+09  음성만을 재생하는 것     694     22       0      0
# 198  2015-12   프랑스  8.523491e+09  음성만을 재생하는 것    1102     27      55      3
# 199  2015-12    호주  8.523491e+09  음성만을 재생하는 것       0      0       3      0
# 200  2015-12    홍콩  8.523491e+09  음성만을 재생하는 것    3549    127      47      3
#
#       무역수지
# 0    23552
# 1       -6
# 2      121
# 3     -172
# 4      -32
# ..     ...
# 196      0
# 197     22
# 198     24
# 199      0
# 200    123
#
# [201 rows x 9 columns]

# %%
df = pd.concat(csv_list)

# %%
df
# Out:
#           기간    국가          HS코드          품목명   수출 중량  수출 금액   수입 중량  수입 금액  \
# 0         총계   NaN           NaN          NaN  746634  28864  122191   5312
# 1    2015-01  네덜란드  8.523491e+09  음성만을 재생하는 것       0      0     154      6
# 2    2015-01    대만  8.523491e+09  음성만을 재생하는 것    4865    121      11      0
# 3    2015-01    독일  8.523491e+09  음성만을 재생하는 것      60      3    4821    175
# 4    2015-01    미국  8.523491e+09  음성만을 재생하는 것    1127     34     999     65
# ..       ...   ...           ...          ...     ...    ...     ...    ...
# 272  2023-12   캐나다  8.523491e+09   음성만을 기록한 것   10140    315      13      1
# 273  2023-12    태국  8.523491e+09   음성만을 기록한 것    4774     78       1      0
# 274  2023-12   프랑스  8.523491e+09   음성만을 기록한 것    8018    284      31      2
# 275  2023-12    호주  8.523491e+09   음성만을 기록한 것    3821    138       0      0
# 276  2023-12    홍콩  8.523491e+09   음성만을 기록한 것   10906    362      12      2
#
#       무역수지
# 0    23552
# 1       -6
# 2      121
# 3     -172
# 4      -32
# ..     ...
# 272    315
# 273     78
# 274    283
# 275    138
# 276    360
#
# [2291 rows x 9 columns]

# %%
df = df.drop(0)

# %%
df
# Out:
#           기간    국가          HS코드          품목명  수출 중량  수출 금액  수입 중량  수입 금액  \
# 1    2015-01  네덜란드  8.523491e+09  음성만을 재생하는 것      0      0    154      6
# 2    2015-01    대만  8.523491e+09  음성만을 재생하는 것   4865    121     11      0
# 3    2015-01    독일  8.523491e+09  음성만을 재생하는 것     60      3   4821    175
# 4    2015-01    미국  8.523491e+09  음성만을 재생하는 것   1127     34    999     65
# 5    2015-01   스페인  8.523491e+09  음성만을 재생하는 것      0      0      1      0
# ..       ...   ...           ...          ...    ...    ...    ...    ...
# 272  2023-12   캐나다  8.523491e+09   음성만을 기록한 것  10140    315     13      1
# 273  2023-12    태국  8.523491e+09   음성만을 기록한 것   4774     78      1      0
# 274  2023-12   프랑스  8.523491e+09   음성만을 기록한 것   8018    284     31      2
# 275  2023-12    호주  8.523491e+09   음성만을 기록한 것   3821    138      0      0
# 276  2023-12    홍콩  8.523491e+09   음성만을 기록한 것  10906    362     12      2
#
#      무역수지
# 1      -6
# 2     121
# 3    -172
# 4     -32
# 5       0
# ..    ...
# 272   315
# 273    78
# 274   283
# 275   138
# 276   360
#
# [2282 rows x 9 columns]

# %%
df['Date'] = pd.to_datetime(df['기간'], format='%Y-%m')

# %%
df
# Out:
#           기간    국가          HS코드          품목명  수출 중량  수출 금액  수입 중량  수입 금액  \
# 1    2015-01  네덜란드  8.523491e+09  음성만을 재생하는 것      0      0    154      6
# 2    2015-01    대만  8.523491e+09  음성만을 재생하는 것   4865    121     11      0
# 3    2015-01    독일  8.523491e+09  음성만을 재생하는 것     60      3   4821    175
# 4    2015-01    미국  8.523491e+09  음성만을 재생하는 것   1127     34    999     65
# 5    2015-01   스페인  8.523491e+09  음성만을 재생하는 것      0      0      1      0
# ..       ...   ...           ...          ...    ...    ...    ...    ...
# 272  2023-12   캐나다  8.523491e+09   음성만을 기록한 것  10140    315     13      1
# 273  2023-12    태국  8.523491e+09   음성만을 기록한 것   4774     78      1      0
# 274  2023-12   프랑스  8.523491e+09   음성만을 기록한 것   8018    284     31      2
# 275  2023-12    호주  8.523491e+09   음성만을 기록한 것   3821    138      0      0
# 276  2023-12    홍콩  8.523491e+09   음성만을 기록한 것  10906    362     12      2
#
#      무역수지       Date
# 1      -6 2015-01-01
# 2     121 2015-01-01
# 3    -172 2015-01-01
# 4     -32 2015-01-01
# 5       0 2015-01-01
# ..    ...        ...
# 272   315 2023-12-01
# 273    78 2023-12-01
# 274   283 2023-12-01
# 275   138 2023-12-01
# 276   360 2023-12-01
#
# [2282 rows x 10 columns]

# %%
# Example mapping dictionaries
country_to_english = {
    "네덜란드": "Netherlands",
    "독일": "Germany",
    "러시아 연방": "Russia",
    "스페인": "Spain",
    "영국": "UK",
    "이탈리아": "Italy",
    "프랑스": "France",
    "베트남": "Vietnam",
    "싱가포르": "Singapore",
    "일본": "Japan",
    "중국": "China",
    "홍콩": "Hong Kong",
    "대만": "Taiwan",
    "사우디아라비아": "Saudi Arabia",
    "인도": "India",
    "인도네시아": "Indonesia",
    "태국": "Thailand",
    "호주": "Australia",
    "멕시코": "Mexico",
    "미국": "USA",
    "캐나다": "Canada",
    "브라질": "Brazil",
    "아르헨티나": "Argentina"
}

country_to_iso = {
    "Netherlands": "NL",
    "Germany": "DE",
    "Russia": "RU",
    "Spain": "ES",
    "UK": "GB",
    "Italy": "IT",
    "France": "FR",
    "Vietnam": "VN",
    "Singapore": "SG",
    "Japan": "JP",
    "China": "CN",
    "Hong Kong": "HK",
    "Taiwan": "TW",
    "Saudi Arabia": "SA",
    "India": "IN",
    "Indonesia": "ID",
    "Thailand": "TH",
    "Australia": "AU",
    "Mexico": "MX",
    "USA": "US",
    "Canada": "CA",
    "Brazil": "BR",
    "Argentina": "AR"
}

continent_group = {
    "Netherlands": "Europe",
    "Germany": "Europe",
    "Russia": "Europe",
    "Spain": "Europe",
    "UK": "Europe",
    "Italy": "Europe",
    "France": "Europe",
    "Vietnam": "East Asia",
    "Singapore": "East Asia",
    "Japan": "East Asia",
    "China": "East Asia",
    "Hong Kong": "East Asia",
    "Taiwan": "East Asia",
    "Saudi Arabia": "S Asia & Oceania",
    "India": "S Asia & Oceania",
    "Indonesia": "S Asia & Oceania",
    "Thailand": "S Asia & Oceania",
    "Australia": "S Asia & Oceania",
    "Mexico": "North America",
    "USA": "North America",
    "Canada": "North America",
    "Brazil": "South America",
    "Argentina": "South America"
}

# Goal 1: Change country name to English
df['Country'] = df['국가'].map(country_to_english)

# Goal 2: Initialize another column with ISO 3166 2-letter country code
df['ISO_Code'] = df['Country'].map(country_to_iso)

# Goal 3: Another column with each country's continent group
df['Continent'] = df['Country'].map(continent_group)

# Display the DataFrame
df
# Out:
#           기간    국가          HS코드          품목명  수출 중량  수출 금액  수입 중량  수입 금액  \
# 1    2015-01  네덜란드  8.523491e+09  음성만을 재생하는 것      0      0    154      6
# 2    2015-01    대만  8.523491e+09  음성만을 재생하는 것   4865    121     11      0
# 3    2015-01    독일  8.523491e+09  음성만을 재생하는 것     60      3   4821    175
# 4    2015-01    미국  8.523491e+09  음성만을 재생하는 것   1127     34    999     65
# 5    2015-01   스페인  8.523491e+09  음성만을 재생하는 것      0      0      1      0
# ..       ...   ...           ...          ...    ...    ...    ...    ...
# 272  2023-12   캐나다  8.523491e+09   음성만을 기록한 것  10140    315     13      1
# 273  2023-12    태국  8.523491e+09   음성만을 기록한 것   4774     78      1      0
# 274  2023-12   프랑스  8.523491e+09   음성만을 기록한 것   8018    284     31      2
# 275  2023-12    호주  8.523491e+09   음성만을 기록한 것   3821    138      0      0
# 276  2023-12    홍콩  8.523491e+09   음성만을 기록한 것  10906    362     12      2
#
#      무역수지       Date      Country ISO_Code         Continent
# 1      -6 2015-01-01  Netherlands       NL            Europe
# 2     121 2015-01-01       Taiwan       TW         East Asia
# 3    -172 2015-01-01      Germany       DE            Europe
# 4     -32 2015-01-01          USA       US     North America
# 5       0 2015-01-01        Spain       ES            Europe
# ..    ...        ...          ...      ...               ...
# 272   315 2023-12-01       Canada       CA     North America
# 273    78 2023-12-01     Thailand       TH  S Asia & Oceania
# 274   283 2023-12-01       France       FR            Europe
# 275   138 2023-12-01    Australia       AU  S Asia & Oceania
# 276   360 2023-12-01    Hong Kong       HK         East Asia
#
# [2282 rows x 13 columns]

# %%
df = df.rename(columns={'수출 금액': 'Export', '수입 금액': 'Import', '무역수지': 'Balance'})
df
# Out:
#           기간    국가          HS코드          품목명  수출 중량  Export  수입 중량  Import  \
# 1    2015-01  네덜란드  8.523491e+09  음성만을 재생하는 것      0       0    154       6
# 2    2015-01    대만  8.523491e+09  음성만을 재생하는 것   4865     121     11       0
# 3    2015-01    독일  8.523491e+09  음성만을 재생하는 것     60       3   4821     175
# 4    2015-01    미국  8.523491e+09  음성만을 재생하는 것   1127      34    999      65
# 5    2015-01   스페인  8.523491e+09  음성만을 재생하는 것      0       0      1       0
# ..       ...   ...           ...          ...    ...     ...    ...     ...
# 272  2023-12   캐나다  8.523491e+09   음성만을 기록한 것  10140     315     13       1
# 273  2023-12    태국  8.523491e+09   음성만을 기록한 것   4774      78      1       0
# 274  2023-12   프랑스  8.523491e+09   음성만을 기록한 것   8018     284     31       2
# 275  2023-12    호주  8.523491e+09   음성만을 기록한 것   3821     138      0       0
# 276  2023-12    홍콩  8.523491e+09   음성만을 기록한 것  10906     362     12       2
#
#      Balance       Date      Country ISO_Code         Continent
# 1         -6 2015-01-01  Netherlands       NL            Europe
# 2        121 2015-01-01       Taiwan       TW         East Asia
# 3       -172 2015-01-01      Germany       DE            Europe
# 4        -32 2015-01-01          USA       US     North America
# 5          0 2015-01-01        Spain       ES            Europe
# ..       ...        ...          ...      ...               ...
# 272      315 2023-12-01       Canada       CA     North America
# 273       78 2023-12-01     Thailand       TH  S Asia & Oceania
# 274      283 2023-12-01       France       FR            Europe
# 275      138 2023-12-01    Australia       AU  S Asia & Oceania
# 276      360 2023-12-01    Hong Kong       HK         East Asia
#
# [2282 rows x 13 columns]

# %%
df_reconstructed = df.loc[:, ['Date', 'Country', 'ISO_Code', 'Continent', 'Export', 'Import', 'Balance']]
df_reconstructed
# Out:
#           Date      Country ISO_Code         Continent  Export  Import  \
# 1   2015-01-01  Netherlands       NL            Europe       0       6
# 2   2015-01-01       Taiwan       TW         East Asia     121       0
# 3   2015-01-01      Germany       DE            Europe       3     175
# 4   2015-01-01          USA       US     North America      34      65
# 5   2015-01-01        Spain       ES            Europe       0       0
# ..         ...          ...      ...               ...     ...     ...
# 272 2023-12-01       Canada       CA     North America     315       1
# 273 2023-12-01     Thailand       TH  S Asia & Oceania      78       0
# 274 2023-12-01       France       FR            Europe     284       2
# 275 2023-12-01    Australia       AU  S Asia & Oceania     138       0
# 276 2023-12-01    Hong Kong       HK         East Asia     362       2
#
#      Balance
# 1         -6
# 2        121
# 3       -172
# 4        -32
# 5          0
# ..       ...
# 272      315
# 273       78
# 274      283
# 275      138
# 276      360
#
# [2282 rows x 7 columns]

# %%
df_reconstructed.to_csv('../album_data_23/df_reconstructed.csv', index=False)

# %%
# Group by Date and Continent, then sum up Exports, Imports, and Balance
continent_summary = df.groupby(['Date', 'Continent']).agg({
    'Export': 'sum',
    'Import': 'sum',
    'Balance': 'sum'
}).reset_index()

# Pivot the table for easier plotting
pivot_df = continent_summary.pivot(index='Date', columns='Continent', values='Export')

# Plotting
pivot_df.plot(figsize=(14, 8), marker='o')
plt.title('Growth of Music Record Exports by Continent')
plt.xlabel('Date')
plt.ylabel('Total Export Value (1000 USD)')
plt.legend(title='Continent', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()  # Adjust layout to make room for the legend
plt.show()

# %%
df_japan = df_reconstructed[df_reconstructed['Country'] == 'Japan']
df_japan.plot(x='Date', y='Export', kind='line', figsize=(10, 6))
plt.title('Export Value of Music Records in Japan')
plt.xlabel('Date')
plt.ylabel('Export Value (1000 USD)')
plt.grid(True)
plt.show()

# %%
df_taiwan = df_reconstructed[df_reconstructed['Country'] == 'Taiwan']
#draw more smooth graph
df_taiwan.plot(x='Date', y='Export', kind='line', figsize=(10, 6), marker='o')
plt.title('Export Value of Music Records in Taiwan')
plt.xlabel('Date')
plt.ylabel('Export Value (1000 USD)')
plt.grid(True)
plt.show()

# %%
df_reconstructed = pd.read_csv("../album_data_23/album_export_23countries.csv")
df_reconstructed['date'] = pd.to_datetime(df_reconstructed['date'], format='%Y-%m-%d')

df_japan = df_reconstructed[df_reconstructed['country'] == 'Japan']
fig, ax1 = plt.subplots(figsize=(12, 8))

ax1.plot(df_japan['date'], df_japan['export'], color='orangered', marker='o')
plt.ylabel('Export Value (1000 USD)')
#plt.grid(True)

ax2 = ax1.twinx()  

df_taiwan = df_reconstructed[df_reconstructed['country'] == 'Taiwan']
ax2.plot(df_taiwan['date'], df_taiwan['export'], color='royalblue', marker='v')
#set ax2 ylim same as ax1
ax2.set_ylim(ax1.get_ylim())
plt.title('Export Value of Music Records in Japan & Taiwan, 2015 - 2023')
plt.xlabel('Date')
# x label by year
plt.ylabel('Export Value (1000 USD)')
plt.grid(True)
plt.legend(['Taiwan', 'Japan'], loc='upper left')
plt.show()

# %%
df_japan[(df_japan['Date'].dt.year >= 2020) & (df_japan['Date'].dt.year <= 2023)]
# Out:
#           Date Country ISO_Code  Continent  Export  Import  Balance
# 17  2020-01-01   Japan       JP  East Asia    3852      72     3780
# 40  2020-02-01   Japan       JP  East Asia    6137     148     5989
# 62  2020-03-01   Japan       JP  East Asia    2588     119     2469
# 84  2020-04-01   Japan       JP  East Asia    1912     134     1778
# 107 2020-05-01   Japan       JP  East Asia    2415      39     2376
# 130 2020-06-01   Japan       JP  East Asia    8842      41     8800
# 153 2020-07-01   Japan       JP  East Asia    1860     140     1720
# 176 2020-08-01   Japan       JP  East Asia    1671     141     1530
# 199 2020-09-01   Japan       JP  East Asia    3946     268     3678
# 222 2020-10-01   Japan       JP  East Asia   16631     244    16387
# 245 2020-11-01   Japan       JP  East Asia   10045     140     9905
# 268 2020-12-01   Japan       JP  East Asia    4282     169     4113
# 17  2021-01-01   Japan       JP  East Asia    4624     174     4450
# 39  2021-02-01   Japan       JP  East Asia    3491     248     3243
# 62  2021-03-01   Japan       JP  East Asia    4047     187     3859
# 85  2021-04-01   Japan       JP  East Asia    6018     245     5773
# 108 2021-05-01   Japan       JP  East Asia    9288     189     9099
# 131 2021-06-01   Japan       JP  East Asia   11167     980    10187
# 154 2021-07-01   Japan       JP  East Asia    5778     158     5619
# 177 2021-08-01   Japan       JP  East Asia    5541     287     5253
# 200 2021-09-01   Japan       JP  East Asia   11877     118    11759
# 223 2021-10-01   Japan       JP  East Asia    5204     133     5072
# 246 2021-11-01   Japan       JP  East Asia    4534     385     4149
# 269 2021-12-01   Japan       JP  East Asia    6481     121     6359
# 17  2022-01-01   Japan       JP  East Asia    3702      35     3667
# 40  2022-02-01   Japan       JP  East Asia    2427     110     2317
# 63  2022-03-01   Japan       JP  East Asia    5568      30     5539
# 86  2022-04-01   Japan       JP  East Asia    6903      23     6880
# 109 2022-05-01   Japan       JP  East Asia   20884      29    20855
# 132 2022-06-01   Japan       JP  East Asia    8864     129     8735
# 155 2022-07-01   Japan       JP  East Asia    8331      21     8311
# 178 2022-08-01   Japan       JP  East Asia    3691      39     3653
# 201 2022-09-01   Japan       JP  East Asia    7422     123     7299
# 224 2022-10-01   Japan       JP  East Asia    6465      11     6454
# 247 2022-11-01   Japan       JP  East Asia    3255     203     3053
# 270 2022-12-01   Japan       JP  East Asia    6514      84     6430
# 17  2023-01-01   Japan       JP  East Asia    5009      28     4981
# 40  2023-02-01   Japan       JP  East Asia    2764     195     2568
# 63  2023-03-01   Japan       JP  East Asia   13511      53    13458
# 86  2023-04-01   Japan       JP  East Asia    9791      36     9754
# 109 2023-05-01   Japan       JP  East Asia    6658      87     6571
# 132 2023-06-01   Japan       JP  East Asia   10790     115    10675
# 155 2023-07-01   Japan       JP  East Asia   15110      32    15078
# 178 2023-08-01   Japan       JP  East Asia   12909     137    12772
# 201 2023-09-01   Japan       JP  East Asia   18610     862    17748
# 224 2023-10-01   Japan       JP  East Asia   10553     723     9831
# 247 2023-11-01   Japan       JP  East Asia    9957      33     9924
# 270 2023-12-01   Japan       JP  East Asia    3511      51     3461

# %%
df_taiwan[(df_taiwan['Date'].dt.year >= 2020) & (df_taiwan['Date'].dt.year <= 2023)]
# Out:
#           Date Country ISO_Code  Continent  Export  Import  Balance
# 2   2020-01-01  Taiwan       TW  East Asia     346       0      346
# 25  2020-02-01  Taiwan       TW  East Asia     788       0      788
# 48  2020-03-01  Taiwan       TW  East Asia     457       0      457
# 70  2020-04-01  Taiwan       TW  East Asia     599       0      599
# 92  2020-05-01  Taiwan       TW  East Asia     564       0      564
# 115 2020-06-01  Taiwan       TW  East Asia     871       4      867
# 138 2020-07-01  Taiwan       TW  East Asia     529       0      529
# 161 2020-08-01  Taiwan       TW  East Asia     504      22      482
# 184 2020-09-01  Taiwan       TW  East Asia     599       0      599
# 207 2020-10-01  Taiwan       TW  East Asia    1018       0     1018
# 230 2020-11-01  Taiwan       TW  East Asia     830      17      813
# 253 2020-12-01  Taiwan       TW  East Asia     999       2      997
# 2   2021-01-01  Taiwan       TW  East Asia     409       2      407
# 25  2021-02-01  Taiwan       TW  East Asia     446       0      446
# 47  2021-03-01  Taiwan       TW  East Asia    1152       0     1152
# 70  2021-04-01  Taiwan       TW  East Asia     837       0      836
# 93  2021-05-01  Taiwan       TW  East Asia     462       0      462
# 116 2021-06-01  Taiwan       TW  East Asia     941       3      939
# 139 2021-07-01  Taiwan       TW  East Asia     573       0      573
# 162 2021-08-01  Taiwan       TW  East Asia     791       0      791
# 185 2021-09-01  Taiwan       TW  East Asia     575       0      575
# 208 2021-10-01  Taiwan       TW  East Asia     570       2      568
# 231 2021-11-01  Taiwan       TW  East Asia     929       1      929
# 254 2021-12-01  Taiwan       TW  East Asia    1616       1     1615
# 2   2022-01-01  Taiwan       TW  East Asia     256       3      253
# 25  2022-02-01  Taiwan       TW  East Asia     651       0      651
# 48  2022-03-01  Taiwan       TW  East Asia    1007       7     1000
# 71  2022-04-01  Taiwan       TW  East Asia     485       0      485
# 94  2022-05-01  Taiwan       TW  East Asia     843       0      843
# 117 2022-06-01  Taiwan       TW  East Asia     905       0      905
# 140 2022-07-01  Taiwan       TW  East Asia     964       0      964
# 163 2022-08-01  Taiwan       TW  East Asia     773       0      773
# 186 2022-09-01  Taiwan       TW  East Asia     544       1      544
# 209 2022-10-01  Taiwan       TW  East Asia     716       0      716
# 232 2022-11-01  Taiwan       TW  East Asia     576       0      576
# 255 2022-12-01  Taiwan       TW  East Asia     937       0      937
# 2   2023-01-01  Taiwan       TW  East Asia     874       0      874
# 25  2023-02-01  Taiwan       TW  East Asia     902       0      902
# 48  2023-03-01  Taiwan       TW  East Asia     770       1      769
# 71  2023-04-01  Taiwan       TW  East Asia     893       0      893
# 94  2023-05-01  Taiwan       TW  East Asia     941       0      941
# 117 2023-06-01  Taiwan       TW  East Asia    1167       0     1167
# 140 2023-07-01  Taiwan       TW  East Asia    1197       6     1191
# 163 2023-08-01  Taiwan       TW  East Asia    1297       1     1297
# 186 2023-09-01  Taiwan       TW  East Asia     710       0      710
# 209 2023-10-01  Taiwan       TW  East Asia    2381       0     2380
# 232 2023-11-01  Taiwan       TW  East Asia    1434       0     1434
# 255 2023-12-01  Taiwan       TW  East Asia     681       0      681

# %%
# Filter the data for the years 2020-2023 and the specified regions
filtered_df = df_reconstructed[(df_reconstructed['Date'].dt.year >= 2020) & (df_reconstructed['Date'].dt.year <= 2023)]
filtered_df = filtered_df[(filtered_df['Continent'] == 'East Asia') | (filtered_df['Continent'] == 'S Asia & Oceania')]

# Group the data by country and calculate the sum of exports
grouped_df = filtered_df.groupby('Country')['Export'].sum().reset_index()

# Plotting the pie chart
plt.figure(figsize=(10, 6))
plt.pie(grouped_df['Export'], labels=grouped_df['Country'], autopct='%1.1f%%')
plt.title('Export Share of Music Records in East Asia and S Asia & Oceania (2020-2023)')
plt.show()

# %%
# Filter the data for the years 2020-2023 and the specified regions
filtered_df = df_reconstructed[(df_reconstructed['Date'].dt.year >= 2020) & (df_reconstructed['Date'].dt.year <= 2023)]
filtered_df = filtered_df[(filtered_df['Continent'] == 'Europe') | (filtered_df['Continent'] == 'North America')]

# Group the data by country and calculate the sum of exports
grouped_df = filtered_df.groupby('Country')['Export'].sum().reset_index()

# Plotting the pie chart
plt.figure(figsize=(10, 6))
plt.pie(grouped_df['Export'], labels=grouped_df['Country'], autopct='%1.1f%%')
plt.title('Export Share of Music Records in Europe and North America (2020-2023)')
plt.show()

# %%
# Filter the data for the years 2020-2023
filtered_df = df_reconstructed[(df_reconstructed['Date'].dt.year >= 2020) & (df_reconstructed['Date'].dt.year <= 2023)]

# Group the data by continent and calculate the sum of exports
grouped_df = filtered_df.groupby('Continent')['Export'].sum().reset_index()

# Plotting the pie chart
plt.figure(figsize=(10, 6))
plt.pie(grouped_df['Export'], labels=grouped_df['Continent'], autopct='%1.1f%%')
plt.title('Export Share of Music Records by Continent (2020-2023)')
plt.show()

# %%
# Filter the data for Japan and the years 2021-2023
df_japan_filtered = df_japan[(df_japan['Date'].dt.year >= 2021) & (df_japan['Date'].dt.year <= 2023)]

# Set the figure size
plt.figure(figsize=(10, 6))

# Plot the monthly sales using seaborn
sns.lineplot(data=df_japan_filtered, x='Date', y='Export')

# Set the title and labels
plt.title('Monthly Sales in Japan (2021-2023)')
plt.xlabel('Date')
plt.ylabel('Export Value (1000 USD)')

# Rotate the x-axis labels for better visibility
plt.xticks(rotation=45)

# Show the plot
plt.show()
# Out:
# /Users/sebang/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/sebang/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Filter the data for Japan, Taiwan, and the USA and the years 2020-2023
filtered_df = df_reconstructed[(df_reconstructed['Country'].isin(['Japan', 'Taiwan', 'USA'])) & (df_reconstructed['Date'].dt.year >= 2020) & (df_reconstructed['Date'].dt.year <= 2023)]

# Pivot the data to have countries as columns and export values as values
pivot_df = filtered_df.pivot(index='Date', columns='Country', values='Export')

# Calculate the correlation matrix
correlation_matrix = pivot_df.corr()

# Display the correlation matrix
correlation_matrix
# Out:
# Country     Japan    Taiwan       USA
# Country
# Japan    1.000000  0.362173  0.560111
# Taiwan   0.362173  1.000000  0.574697
# USA      0.560111  0.574697  1.000000

# %%
sns.heatmap(correlation_matrix, annot = True, cmap = 'viridis')
# Out:
# <Axes: xlabel='Country', ylabel='Country'>

# %%
#유튜브와 앨범데이터 사이에 시차 넣기?
