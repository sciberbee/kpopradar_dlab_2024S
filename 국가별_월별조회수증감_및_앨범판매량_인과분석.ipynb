# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
allcountries_views_df = pd.read_csv("../original_data/youtube_musicvideo_countries_daily_increasedviews.csv")

# %%
allcountries_views_df['artist_name'].unique()
# Out:
# array(['카더가든', '폴킴', 'TWICE (트와이스)', '웨터 (wetter)', '청하', '윤딴딴',
#        'Wanna One (워너원)', '엔플라잉 (N.Flying)', '에일리', '에릭남 (Eric Nam)',
#        '소유 (SOYOU)', '브라더수', '정은지', '김나영', '권진아', '곽진언', '김동률',
#        '키썸 (Kisum)', '먼데이키즈 (Monday Kiz)', '양요섭', '비투비', 'Jvcki Wai',
#        '지바노프 (jeebanoff)', '이진아', 'SUMIN (수민)', '안녕하신가영', '새소년', 'ADOY',
#        '스텔라장 (Stella Jang)', '코드 쿤스트 (CODE KUNST)', 'DAY6 (데이식스)',
#        '오왠 (O.WHEN)', '실리카겔', '서사무엘 (Samuel Seo)', 'GSoul', '적재',
#        '팔로알토 (Paloalto)', 'San E', '선우정아', '솔루션스 (THE SOLUTIONS)', '박지윤',
#        '정기고', '옥상달빛', '조정치', '브로콜리너마저', '디어클라우드', 'EXO', '방탄소년단',
#        '동방신기 (TVXQ!)', 'BIGBANG', '인피니트', 'B1A4', '블락비 (Block B)', '뉴이스트',
#        '2PM', 'SUPER JUNIOR (슈퍼주니어)', '틴탑', 'SHINee (샤이니)',
#        '아스트로 (ASTRO)', 'FTISLAND (FT아일랜드)', 'CNBLUE (씨엔블루)', '2AM',
#        '넬 (NELL)', '골든차일드', 'WINNER', "소녀시대 (GIRLS' GENERATION)",
#        'Apink (에이핑크)', '마마무(Mamamoo)', '여자친구 (GFRIEND)', '러블리즈', 'AOA',
#        '오마이걸', 'EXID', 'Red Velvet (레드벨벳)', '구구단 (gugudan)', '우주소녀',
#        '티아라', '에이프릴 (APRIL)', '다비치', 'DIA (다이아)', 'BLACKPINK',
#        '위키미키 (Weki Meki)', '라붐(LABOUM)', 'CLC', '소나무 (SONAMOO)',
#        '모모랜드 (MOMOLAND)', '레이디스 코드', '드림캐쳐', '베리굿 (BerryGood)',
#        '엘리스 (ELRIS)', '소녀주의보', 'FAVORITE (페이버릿)', '(여자)아이들', '육성재',
#        '몬스타엑스', 'JBJ', '젝스키스', '업텐션 (UP10TION)', 'VIXX(빅스)', 'iKON', '신화',
#        '더보이즈(THE BOYZ)', '정세운', 'SF9', 'god', 'Stray Kids (스트레이 키즈)',
#        '펜타곤', '스누퍼 (SNUPER)', 'VICTON (빅톤)', 'A.C.E (에이스)', '아이유',
#        '프로미스나인', '이달의 소녀', '하이라이트 (Highlight)', '10cm',
#        '공원소녀(Girls in the Park)', 'ATEEZ (에이티즈)', 'IZ*ONE (아이즈원)',
#        '수호 (SUHO)', '찬열 (CHANYEOL)', '카이 (KAI)', '백현 (BAEKHYUN)',
#        '시우민 (XIUMIN)', '첸 (CHEN)', 'RM', '진', 'j-hope', '지민', 'V',
#        '나연 (TWICE)', '웬디 (WENDY)', '슬기 (SEULGI)', '조이 (JOY)', '예리 (YERI)',
#        '진솔 (이달의 소녀)', '츄(Chuu)', '황인욱', '안예은', 'JIDA (지다)', 'SOLE (쏠)',
#        'Sondia', '이바다', '양다일', '한해', '박지훈', 'JAY B (GOT7)', '마크 (GOT7)',
#        '잭슨 (Jackson Wang)', '진영 (GOT7)', '뱀뱀 (BamBam)', '유겸 (Yugyeom)',
#        '영재 (GOT7)', 'GOT7 (갓세븐)', '태일 (TAEIL)', '태용 (TAEYONG)',
#        '도영 (DOYOUNG)', '텐 (TEN)', '재현 (JAEHYUN)', '마크 (MARK)', '김재환',
#        '강다니엘', '윤지성', '드림노트 (DreamNote)', 'NATURE (네이처)', '버스터즈',
#        '케이시 (Kassy)', '임재현', '옹성우', '하성운', '체리블렛 (Cherry Bullet)',
#        '원어스 (ONEUS)', '원위 (ONEWE)', 'Young K', '원필', '효진', '온앤오프 (ONF)',
#        'ITZY (있지)', 'WOOZI (SEVENTEEN)', '디에잇 (SEVENTEEN)',
#        '도겸 (SEVENTEEN)', '승관 (SEVENTEEN)', 'Vernon (SEVENTEEN)', '세븐틴',
#        'HYNN (박혜원)', '보라미유', '투모로우바이투게더', '민서', 'JBJ95',
#        'EVERGLOW (에버글로우)', '리사 (LISA)', '제니 (JENNIE)', '지수 (JISOO)',
#        '로제 (ROSÉ)', 'I.M (몬스타엑스)', '원호 (WONHO)', '기현 (몬스타엑스)', '강혜원',
#        'YENA (최예나)', '이채연', '조유리', '미연 ((여자)아이들)', '이승협 (J.DON)',
#        '김남주 (에이핑크)', '오하영 (에이핑크)', '서은광 (비투비)', '이민혁 (HUTA)', '임현식 (비투비)',
#        '프니엘 (PENIEL)', '이창섭', '유노윤호 (U-KNOW)', '최강창민 (MAX)', '남우현',
#        '엘 (인피니트)', '진영', '산들', '태일 (블락비)', '유권 (블락비)', '박경', '백호 (뉴이스트)',
#        '황민현', '준케이 (JUN. K)', '닉쿤 (2PM)', '준호 (2PM)', '예성 (YESUNG)',
#        '은혁 (EUNHYUK)', '동해 (DONGHAE)', '려욱 (RYEOWOOK)', '규현 (KYUHYUN)',
#        '니엘', '온유 (ONEW)', '종현 (JONGHYUN)', '태민 (TAEMIN)', 'MJ (of 아스트로)',
#        '진진 (ASTRO)', '차은우 (ASTRO)', '라키', '수현 (U-Kiss)', 'MINO (송민호)',
#        '강승윤', '태연 (TAEYEON)', '효연 (HYO)', '유리 (YURI)', '윤아 (YOONA)',
#        '서현 (SEOHYUN)', '솔라 (마마무)', '휘인 (Whee In)', '화사 (Hwa Sa)',
#        '예린 (YERIN)', '은하 (여자친구)', '유주 (YUJU)', '엄지 (여자친구)', '이수정 (러블리즈)',
#        'Kei (김지연)', '정예인 (Yein)', '효정 (오마이걸)', '유아 (오마이걸)', '승희 (오마이걸)',
#        '솔지', '김세정', '유연정 (우주소녀)', '효민', '김채원 (에이프릴)', '이진솔 (에이프릴)',
#        '예은 (YEEUN)', '엘키 (CLC)', '전소연', '우기', '이진혁', '라비 (RAVI)',
#        '홍빈 (HONGBIN)', 'BOBBY', 'B.I', '김동완', '신혜성', '김우진', '후이 (펜타곤)',
#        '키노 (펜타곤)', '한승우', '이기광', '원더나인 (1THE9)', 'NCT DREAM', '구구단 세미나',
#        '박효신', '볼빨간사춘기', 'Crush', '지코 (ZICO)', '이수현', '악뮤', 'DEAN',
#        'Zion.T', '헤이즈 (Heize)', '빈지노 (Beenzino)', '로꼬', '오혁',
#        '혁오 (HYUKOH)', '성시경', '에픽하이 (EPIK HIGH)', '어반 자카파 ', '기리보이', '박재범',
#        '케이윌', '임창정', '정승환', '백예린', '최자', '개코', '다이나믹 듀오', '윤종신', '로이킴',
#        'BewhY (비와이)', 'CHEEZE (치즈)', 'Dok2', '벤', '프라이머리', '멜로망스', '장범준',
#        '정준일', '황치열', '민경훈', '버즈 ', '허각', '거미', '창모 (CHANGMO)',
#        '빈첸 (VINXEN)', '신용재', 'DPR LIVE', '잔나비', '우원재', 'Kid Milli', '이하이',
#        '우효', '검정치마', '정엽', '개리', '박원', '김하온 (HAON)', 'The Quiett',
#        '스웨덴세탁소', '이석훈', '김용준', 'SG 워너비', '선미', '에피톤 프로젝트', '싸이 (PSY)',
#        'SURAN (수란)', '식케이 (Sik-K)', '휘성 (Realslow)', '환희', '플라이 투 더 스카이',
#        '김범수', 'EXO-CBX', '어쿠스틱 콜라보', '나플라(nafla)', 'pH-1', '샘김 (SAM KIM)',
#        '크루셜스타 (Crucial Star)', 'Colde (콜드)', '한동근', '오왼 (Owen)',
#        '소란 (SORAN)', '부석순 (SEVENTEEN)', '비투비-블루', '오마이걸 반하나',
#        '소녀시대-Oh!GG', '블락비 바스타즈', 'SUPER JUNIOR-D&E (동해&은혁)', '스탠딩 에그',
#        'VERIVERY ', '박봄', 'VAV', 'NCT 127', '바닐라 어쿠스틱', '전소미', '공민지',
#        '수지 (SUZY)', '서인국', 'WOODZ (조승연)', '앤씨아', '방민아 (Bang Minah)',
#        '아이오아이 (I.O.I)', '윤하 (YOUNHA)', '1TEAM', '015B', '효린',
#        '저스디스 (JUSTHIS)', '양홍원', '알리 (ALi)', '지투 (G2)', 'Lim Kim', '장재인',
#        '김요한', '이은상', 'X1 (엑스원)', '로켓펀치 (Rocket Punch)', '에디킴', '홍대광',
#        '마이틴', '보아 (BoA)', '이영지', '박보람', '엠버 (AMBER)', '루나 (LUNA) ',
#        'BVNDIT (밴디트)', '우진영', '디원스 (D1CE)', 'FANATICS (파나틱스)',
#        '핫펠트 (HA:TFELT)', '헨리 (HENRY)', '비', '카라', 'IN2IT (인투잇)',
#        'GRAY (그레이)', '사이먼 도미닉', '유성은', '김동준', '박진영', '조권', '홍진영',
#        '낙준 (버나드 박)', 'Jamie (제이미)', 'SuperM', '뉴키드 (Newkidd)', '김현중',
#        'VIINI (권현빈)', '숀 (SHAUN)', '오반', 'Woodie Gochild', '브라운아이드걸스',
#        '자이언트핑크', '카드 (KARD)', '백아연', '김필', '제이레빗(J Rabbit)',
#        '플로우식 (Flowsik)', '윤건', '걸카인드 (GIRLKIND)', 'VANNER (배너)',
#        'D-CRUNCH (디크런치)', '페노메코 (PENOMECO)', '올티 (Olltii)', 'BUMZU',
#        '하동균', 'Agust D', '사우스클럽 (South Club)', '정동하', 'GHOST9',
#        '세러데이 (SATURDAY)', '제시 (Jessi)', 'Jessica (제시카)', '쿠기 (Coogie)',
#        '하선호 (Sandy)', '현영 (레인보우)', 'Hash Swan', '백지영', '심규선 (Lucia)',
#        '로시 (Rothy)', '이소라', '염따', '존박', '멋진녀석들 (GreatGuys)',
#        '정대현 (JUNG DAE HYUN)', '넉살', 'BIGONE (빅원)', '써니힐',
#        '블랙식스 (BLACK6IX)', 'OnlyOneOf (온리원오브)', 'MC몽', 'ARIAZ (아리아즈)',
#        'BDC', 'WE IN THE ZONE', '국카스텐', 'HINAPIA', '송가인', '딘딘',
#        '비아이지 (B.I.G)', 'DAWN (던)', '하현우 (국카스텐)', '세븐어클락', '비오브유 (B.O.Y)',
#        '솔비', 'ASH ISLAND', '전효성', '성민 (SUNGMIN)', '데이브레이크 (DAYBREAK)',
#        'SMTOWN', '울랄라세션', 'XIA (준수)', '슬리피', '박재정', 'Xydo (시도)', 'MCND',
#        '애즈원', 'BIG Naughty (서동현)', 'ENOi', '일급비밀 (TST)', '임팩트', '이용신',
#        'BZ-BOYS(청공소년)', 'TREASURE (트레저)', '김우석', '김재중', '별', '이효리', '이승기',
#        '이선희', '이승철', '버벌진트', '릴러말즈 (Leellamarz)', '송지은', '행주', '다크비(DKB)',
#        '시그니처 (cignature)', '경리 (나인뮤지스)', '임정희', '옥주현', 'Rohann (이로한)',
#        'YUNHWAY', 'UNEDUCATED KID', '신원호', '이이경', 'UNVS', '이수영',
#        'CRAVITY', '홍은기 (HONG EUNKI)', '신승훈', 'TO1 (티오원)', 'MY.st (마이스트)',
#        'JUNIEL', '임영웅', '이찬원', '영탁', '장민호', '김희재', '나띠 (NATTY)', 'Raiden',
#        'woo!ah! (우아!)', 'SECRET NUMBER (시크릿넘버)', 'REDSQUARE (레드스퀘어)',
#        '방예담', '엘라스트 (E`LAST)', 'Weeekly (위클리)', 'WayV', '조미 (ZHOUMI)',
#        '정동원', '나다 (NADA)', '3YE (써드아이)', '레드벨벳-아이린&슬기', '위아이(WEi)',
#        '퍼플키스', '로코베리', '브브걸', '픽보이 (Peakboy)', 'P1Harmony',
#        '루나솔라 (LUNARSOLAR)', 'DRIPPIN (드리핀)', 'Queen WA$ABII (퀸 와사비)',
#        '문빈&산하(ASTRO)', 'ENHYPEN', '우주소녀 쪼꼬미', 'aespa', '김규종', '코요태',
#        'BAE173', 'KAACHI', '스윗소로우 (SWEET SORROW)', 'STAYC', 'TFN', '남승민',
#        '하현상', 'LUCY', '비투비 포유', '노라조', '선예', '최예근', '김현철', '닐로(Nilo)',
#        'NCT 2020', 'ABLE (장현승)', '엄정화', '바비 킴', '다운(Dvwn)',
#        '미래소년 (MIRAE)', '싸이퍼(Ciipher)', '픽시 (PIXY)', '이승윤', 'LIGHTSUM',
#        'MAJORS', '핫이슈(HOT ISSUE)', '이이언 (eAeon)', '이무진', '트라이비(TRI.BE)',
#        'Seori', '자우림', '핑크판타지', '킹덤 (KINGDOM)', '가비엔제이', '김종국', '이보람',
#        '유선호', '라포엠(LA POEM)', 'Billlie (빌리)', 'lilli lilli (릴리릴리)',
#        'IVE (아이브)', '페퍼톤스 (Peppertones)', '포레스텔라', "BE'O (비오)",
#        'meenoi (미노이)', '장기하', '원슈타인', '임재범', '강지영', 'NewJeans', '니콜',
#        'KCM', 'LIMELIGHT (라임라잇)', 'FIFTY FIFTY', '달수빈', 'EPEX (이펙스)',
#        'JUST B', '셔누 (몬스타엑스)', '첫사랑(CSR)', 'TEMPEST(템페스트)', '키 (Key)',
#        '허영생', '우주소녀 더 블랙 (WJSN THE BLACK)', '전웅 (AB6IX)', '블리처스',
#        'tripleS', '유회승 (N.Flying)', 'Kep1er', 'OMEGA X', '미주 (MIJOO)',
#        'AB6IX (에이비식스)', 'SUPER JUNIOR-K.R.Y. (슈퍼주니어-K.R.Y)',
#        'CIX (씨아이엑스)', '현아', 'APOKI (아뽀키)', '태양', 'NCT U', '죠지', 'DKZ',
#        'PLAVE', '산다라박', '정국', '파시걸스 (PoshGirls)', '루미너스', '권은비',
#        'IRRIS (아이리스)', 'bugAboo (버가부)', "ICHILLIN' (아이칠린)", 'NMIXX',
#        'CLASS:y (클라씨)', 'Xdinary Heroes', 'TAN (티에이엔)',
#        'Rocking doll (록킹돌)', '주헌 (몬스타엑스)', '아이즈(IZ)', 'GOT the beat',
#        'H1-KEY', 'TRENDZ (트렌드지)', '아일리원(ILY:1)', 'YOUNITE', 'VIVIZ',
#        'ATBO', '허윤진', 'Olivia Hye (이달의 소녀)', 'NINE.i (나인아이)',
#        'MAVE: (메이브)', 'THE NEW SIX (TNX)', 'LE SSERAFIM (르세라핌)',
#        'Lapillus(라필루스)', '&TEAM', '이찬혁', '재찬', 'n.SSign (엔싸인)',
#        'xikers(싸이커스)', '디오 (D.O.)', '8TURN', 'HORI7ON(호라이즌)', 'X:IN (엑신)',
#        '마마무+', 'NCT 도재정', 'ZEROBASEONE', '더윈드 (The Wind)',
#        'ODD EYE CIRCLE', '문별 (마마무)', 'LUN8 (루네이트)', 'ADYA (에이디야)',
#        'KISS OF LIFE', '잔나비 최정훈', '블랙스완', 'BOYNEXTDOOR', '지효', 'PERC%NT',
#        '준 (SEVENTEEN)', 'RIIZE (라이즈)', '티아이오티 (TIOT)', '엠블랙', '프림로즈'],
#       dtype=object)

# %%
country_album_sales_df = pd.read_csv("../album_data_23/album_export_23countries.csv")
country_album_sales_df
# Out:
#             date        country ISO_Code         continent  export  import  \
# 0     2015-01-01    Netherlands       NL            Europe       0       6
# 1     2015-01-01         Taiwan       TW         East Asia     121       0
# 2     2015-01-01        Germany       DE            Europe       3     175
# 3     2015-01-01  United States       US     North America      34      65
# 4     2015-01-01          Spain       ES            Europe       0       0
# ...          ...            ...      ...               ...     ...     ...
# 2277  2023-12-01         Canada       CA     North America     315       1
# 2278  2023-12-01       Thailand       TH  S Asia & Oceania      78       0
# 2279  2023-12-01         France       FR            Europe     284       2
# 2280  2023-12-01      Australia       AU  S Asia & Oceania     138       0
# 2281  2023-12-01      Hong Kong       HK         East Asia     362       2
#
#       balance
# 0          -6
# 1         121
# 2        -172
# 3         -32
# 4           0
# ...       ...
# 2277      315
# 2278       78
# 2279      283
# 2280      138
# 2281      360
#
# [2282 rows x 7 columns]

# %%
#2021년 4월은 18일부터 카운트되어있으므로, 월별로 합산할 때 확연히 작아진다. 2021년 4월은 제외하는 것이 옳다

allcountries_views_df = allcountries_views_df[allcountries_views_df['date'] >= 20210501]
allcountries_views_df
# Out:
#           artist_id   artist_name         country      date  inc
# 435580            1          카더가든           Italy  20210501   12
# 435581            1          카더가든         Türkiye  20210501   97
# 435582            1          카더가든    Saudi Arabia  20210501   45
# 435583            1          카더가든  United Kingdom  20210501   85
# 435584            1          카더가든       Australia  20210501  396
# ...             ...           ...             ...       ...  ...
# 32236006       2712  티아이오티 (TIOT)          Canada  20230930   15
# 32236007       2712  티아이오티 (TIOT)   United States  20230930   86
# 32236008       2712  티아이오티 (TIOT)          Mexico  20230930   10
# 32236009       2712  티아이오티 (TIOT)       Argentina  20230930  104
# 32236010       2712  티아이오티 (TIOT)          Brazil  20230930   14
#
# [31800431 rows x 5 columns]

# %%
allcountries_views_df['artist_name'].unique().shape
# Out:
# (699,)

# %%
print([s for s in allcountries_views_df['artist_name'].unique() if "방탄" in s])
# Out:
# ['방탄소년단']

# %%
print([c for c in allcountries_views_df['country'].unique() if "United" in c])
# Out:
# ['United Kingdom', 'United Arab Emirates', 'United States']

# %%
# Assuming you have an np.ndarray with string values
arr = allcountries_views_df['country'].unique()

# Convert the array to string type
arr = arr.astype(str)

# Keyword string to search for
keyword = 'United'

# Find strings that contain the keyword
result = arr[np.char.find(arr, keyword) != -1]

print(result)
# Out:
# ['United Kingdom' 'United Arab Emirates' 'United States']

# %%
type(arr[0])
# Out:
# str

# %%
allcountries_views_df[allcountries_views_df['artist_name'] == '방탄소년단']
# Out:
#           artist_id artist_name            country      date    inc
# 2478            273       방탄소년단               Togo  20210418    679
# 2479            273       방탄소년단            Nigeria  20210418  10809
# 2480            273       방탄소년단           Cameroon  20210418    812
# 2481            273       방탄소년단  Equatorial Guinea  20210418     63
# 2482            273       방탄소년단              Gabon  20210418   1576
# ...             ...         ...                ...       ...    ...
# 32200930        273       방탄소년단      Guinea-Bissau  20230930     65
# 32200931        273       방탄소년단       Sierra Leone  20230930    422
# 32200932        273       방탄소년단             Guinea  20230930    130
# 32200933        273       방탄소년단      Côte d'Ivoire  20230930   5229
# 32200934        273       방탄소년단              Ghana  20230930   3407
#
# [167786 rows x 5 columns]

# %%
BTS_Japan_Filtered_df = allcountries_views_df[(allcountries_views_df['artist_name'] == '방탄소년단') & (allcountries_views_df['country'] == 'Japan')]
# Convert the 'date' column to string format
BTS_Japan_Filtered_df['date'] = pd.to_datetime(BTS_Japan_Filtered_df['date'], format='%Y%m%d')
BTS_Japan_Filtered_df
# Out:
# /var/folders/4t/lj2jkv114_3c4yz5pdp55ws80000gn/T/ipykernel_75745/851843074.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BTS_Japan_Filtered_df['date'] = pd.to_datetime(BTS_Japan_Filtered_df['date'], format='%Y%m%d')
#           artist_id artist_name country       date      inc
# 2547            273       방탄소년단   Japan 2021-04-18  3704646
# 35978           273       방탄소년단   Japan 2021-04-19  3515359
# 69446           273       방탄소년단   Japan 2021-04-20  3448977
# 103166          273       방탄소년단   Japan 2021-04-21  4239558
# 136755          273       방탄소년단   Japan 2021-04-22  3849812
# ...             ...         ...     ...        ...      ...
# 32048789        273       방탄소년단   Japan 2023-09-26  1172265
# 32086746        273       방탄소년단   Japan 2023-09-27  1172823
# 32124800        273       방탄소년단   Japan 2023-09-28  1198109
# 32162779        273       방탄소년단   Japan 2023-09-29  1428076
# 32200798        273       방탄소년단   Japan 2023-09-30  1532026
#
# [893 rows x 5 columns]

# %%
filtered_df = BTS_Japan_Filtered_df[BTS_Japan_Filtered_df['date'].dt.strftime('%Y-%m') == '2023-09']
filtered_df
# Out:
#           artist_id artist_name country       date      inc
# 31090589        273       방탄소년단   Japan 2023-09-01  1219503
# 31129302        273       방탄소년단   Japan 2023-09-02  1173119
# 31167848        273       방탄소년단   Japan 2023-09-03  1280183
# 31206287        273       방탄소년단   Japan 2023-09-04  1161804
# 31244680        273       방탄소년단   Japan 2023-09-05  1139211
# 31283152        273       방탄소년단   Japan 2023-09-06  1153210
# 31321721        273       방탄소년단   Japan 2023-09-07  1171611
# 31360427        273       방탄소년단   Japan 2023-09-08  1263498
# 31398934        273       방탄소년단   Japan 2023-09-09  1189544
# 31437314        273       방탄소년단   Japan 2023-09-10  1054088
# 31475699        273       방탄소년단   Japan 2023-09-11  1564466
# 31514125        273       방탄소년단   Japan 2023-09-12  1225338
# 31552633        273       방탄소년단   Japan 2023-09-13  1218385
# 31590958        273       방탄소년단   Japan 2023-09-14  1194443
# 31629578        273       방탄소년단   Japan 2023-09-15  1326807
# 31668055        273       방탄소년단   Japan 2023-09-16  1200811
# 31706411        273       방탄소년단   Japan 2023-09-17  1172735
# 31744601        273       방탄소년단   Japan 2023-09-18  1166121
# 31782563        273       방탄소년단   Japan 2023-09-19  1178438
# 31820557        273       방탄소년단   Japan 2023-09-20  1204287
# 31858644        273       방탄소년단   Japan 2023-09-21  1381639
# 31896771        273       방탄소년단   Japan 2023-09-22  1389606
# 31935073        273       방탄소년단   Japan 2023-09-23  1290229
# 31973095        273       방탄소년단   Japan 2023-09-24  1109399
# 32011100        273       방탄소년단   Japan 2023-09-25  1130901
# 32048789        273       방탄소년단   Japan 2023-09-26  1172265
# 32086746        273       방탄소년단   Japan 2023-09-27  1172823
# 32124800        273       방탄소년단   Japan 2023-09-28  1198109
# 32162779        273       방탄소년단   Japan 2023-09-29  1428076
# 32200798        273       방탄소년단   Japan 2023-09-30  1532026

# %%
filtered_df['inc'].sum()
# Out:
# 37062675

# %%
# Group the dataframe by month and sum the 'inc' column
BTS_Japan_monthly_sum = BTS_Japan_Filtered_df.groupby(pd.Grouper(key='date', freq='M')).sum()

BTS_Japan_youtube_monthly_sum = BTS_Japan_monthly_sum['inc']

BTS_Japan_youtube_monthly_sum
# Out:
# date
# 2021-04-30     50054279
# 2021-05-31    166563733
# 2021-06-30    184461830
# 2021-07-31    221307694
# 2021-08-31    165123042
# 2021-09-30    151154049
# 2021-10-31    133551941
# 2021-11-30    114377125
# 2021-12-31    108815578
# 2022-01-31     96399451
# 2022-02-28     85843829
# 2022-03-31     97211787
# 2022-04-30     86418793
# 2022-05-31     82443701
# 2022-06-30    115934412
# 2022-07-31     71070629
# 2022-08-31     67988890
# 2022-09-30     56773698
# 2022-10-31     57210536
# 2022-11-30     60253319
# 2022-12-31     54332008
# 2023-01-31     46221786
# 2023-02-28     45249644
# 2023-03-31     44218485
# 2023-04-30     40580864
# 2023-05-31     39424193
# 2023-06-30     46077897
# 2023-07-31     41423056
# 2023-08-31     38323298
# 2023-09-30     37062675
# Freq: M, Name: inc, dtype: int64

# %%
plt.figure(figsize=(12, 6))
plt.plot(BTS_Japan_youtube_monthly_sum.index, BTS_Japan_youtube_monthly_sum.values, color='orange', label='Japan')
plt.xlabel('Date')
plt.ylabel('Views')
plt.title('Monthly Views of BTS in Japan')
plt.xticks(rotation=90)
plt.ticklabel_format(style='plain', axis='y')  # Display y-axis labels in plain format
plt.legend()

plt.show()

# %%
import matplotlib.font_manager as fm
f = [f.name for f in fm.fontManager.ttflist]
# print strings containing "nanum" in f
print([s for s in f if "Nanum" in s])

# 확인 이후
plt.rc('font', family='NanumSquare Neo OTF')
# Out:
# ['NanumSquareOTF_ac', 'NanumSquareOTF', 'NanumSquare Neo OTF', 'NanumSquare Neo OTF', 'NanumSquareOTF_ac', 'NanumGothicOTF', 'NanumSquareOTF', 'NanumSquare Neo OTF', 'NanumGothicOTF', 'NanumSquareOTF_ac', 'NanumGothicOTF', 'NanumBarunGothicOTF', 'NanumMyeongjoOTF', 'NanumSquare Neo variable', 'NanumGothicOTF', 'Nanum Brush Script', 'NanumBarunGothicOTF', 'NanumSquareOTF_ac', 'NanumSquare Neo OTF', 'NanumSquareOTF', 'Nanum Gothic', 'NanumMyeongjoOTF', 'NanumSquareRoundOTF', 'NanumSquareRoundOTF', 'Nanum Myeongjo', 'NanumSquareRoundOTF', 'NanumBarunGothicOTF', 'NanumSquareOTF', 'NanumBarunGothicOTF', 'NanumSquare Neo OTF', 'NanumSquareRoundOTF', 'NanumMyeongjoOTF']

# %%
def show_monthly_youtube_graph(artist, country):
    artist_df = allcountries_views_df[(allcountries_views_df['artist_name'] == artist) & (allcountries_views_df['country'] == country)]
    artist_df['date'] = pd.to_datetime(artist_df['date'], format='%Y%m%d')
    artist_monthly_sum = artist_df.groupby(pd.Grouper(key='date', freq='M')).sum()
    artist_youtube_monthly_sum = artist_monthly_sum['inc']
    plt.figure(figsize=(12, 6))
    plt.plot(artist_youtube_monthly_sum.index, artist_youtube_monthly_sum.values, color='orange', label=artist)
    plt.xlabel('Date')
    plt.ylabel('Views')
    plt.title('Monthly Views of ' + artist + ' in ' + country)
    plt.xticks(rotation=90)
    plt.ticklabel_format(style='plain', axis='y')  # Display y-axis labels in plain format
    plt.legend()
    plt.show()

show_monthly_youtube_graph('BLACKPINK', 'Indonesia')
# Out:
# /var/folders/4t/lj2jkv114_3c4yz5pdp55ws80000gn/T/ipykernel_75745/3390250045.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   artist_df['date'] = pd.to_datetime(artist_df['date'], format='%Y%m%d')

# %%
country_album_sales_df = pd.read_csv("../album_data_23/album_export_23countries.csv")
country_album_sales_df
# Out:
#             date      country ISO_Code         continent  export  import  \
# 0     2015-01-01  Netherlands       NL            Europe       0       6
# 1     2015-01-01       Taiwan       TW         East Asia     121       0
# 2     2015-01-01      Germany       DE            Europe       3     175
# 3     2015-01-01          USA       US     North America      34      65
# 4     2015-01-01        Spain       ES            Europe       0       0
# ...          ...          ...      ...               ...     ...     ...
# 2277  2023-12-01       Canada       CA     North America     315       1
# 2278  2023-12-01     Thailand       TH  S Asia & Oceania      78       0
# 2279  2023-12-01       France       FR            Europe     284       2
# 2280  2023-12-01    Australia       AU  S Asia & Oceania     138       0
# 2281  2023-12-01    Hong Kong       HK         East Asia     362       2
#
#       balance
# 0          -6
# 1         121
# 2        -172
# 3         -32
# 4           0
# ...       ...
# 2277      315
# 2278       78
# 2279      283
# 2280      138
# 2281      360
#
# [2282 rows x 7 columns]

# %%
japan_album_sales_df = country_album_sales_df[country_album_sales_df['country'] == 'Japan']
japan_album_sales_df
# Out:
#             date country ISO_Code  continent  export  import  balance
# 8     2015-01-01   Japan       JP  East Asia     887     174      713
# 27    2015-02-01   Japan       JP  East Asia     401     104      297
# 45    2015-03-01   Japan       JP  East Asia    1756     168     1588
# 63    2015-04-01   Japan       JP  East Asia    1064     141      923
# 78    2015-05-01   Japan       JP  East Asia    1807     119     1688
# ...          ...     ...      ...        ...     ...     ...      ...
# 2183  2023-08-01   Japan       JP  East Asia   12909     137    12772
# 2206  2023-09-01   Japan       JP  East Asia   18610     862    17748
# 2229  2023-10-01   Japan       JP  East Asia   10553     723     9831
# 2252  2023-11-01   Japan       JP  East Asia    9957      33     9924
# 2275  2023-12-01   Japan       JP  East Asia    3511      51     3461
#
# [108 rows x 7 columns]

# %%
def show_album_export_graph(country):
    #country_album_sales_df = pd.read_csv("../album_data_23/album_export_23countries.csv")
    country_album_df = country_album_sales_df[country_album_sales_df['country'] == country]
    country_album_df['date'] = pd.to_datetime(country_album_df['date'], format='%Y-%m-%d')
    country_album_df = country_album_df[(country_album_df['date'] >= '2021-05-01') & (country_album_df['date'] <= '2023-10-31')]
    plt.figure(figsize=(12, 6))
    plt.plot(country_album_df['date'], country_album_df['export'])
    plt.xlabel('Date')
    plt.ylabel('Album Sales (1000 USD)')
    plt.title(country + ' Album Sales from 2021-05 to 2023-10')
    plt.xticks(rotation=90)
    plt.show()

show_album_export_graph('Taiwan')
# Out:
# /var/folders/4t/lj2jkv114_3c4yz5pdp55ws80000gn/T/ipykernel_75745/3293054334.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_df['date'] = pd.to_datetime(country_df['date'], format='%Y-%m-%d')

# %%
def show_monthly_youtube_graph(country, start, end):
    country_youtube_df = allcountries_views_df[(allcountries_views_df['country'] == country)]
    country_youtube_df['date'] = pd.to_datetime(country_youtube_df['date'], format='%Y%m%d')
    country_monthly_sum = country_youtube_df.groupby(pd.Grouper(key='date', freq='M')).sum()
    country_monthly_sum = country_monthly_sum[(country_monthly_sum.index >= start) & (country_monthly_sum.index <= end)]
    country_monthly_sum.index = country_monthly_sum.index.to_period('M').to_timestamp()
    country_youtube_monthly_sum = country_monthly_sum['inc']
    
    country_album_df = country_album_sales_df[country_album_sales_df['country'] == country]
    country_album_df['date'] = pd.to_datetime(country_album_df['date'], format='%Y-%m-%d')
    country_album_df = country_album_df[(country_album_df['date'] >= start) & (country_album_df['date'] <= end)]
    
    fig, ax1 = plt.subplots(figsize=(12, 8))  # Create the figure and the first axis

    # Plot the first graph
    ax1.plot(country_youtube_monthly_sum.index, country_youtube_monthly_sum.values, color = 'tab:red', marker = 'o', linestyle = '-', label = "YouTube Viewcount Data Points")  # 'r-' is for red solid line
    ax1.set_xlabel('Month')
    ax1.set_ylabel('Monthly YouTube views increment', color='tab:red')  # Set the label for the y-axis
    ax1.set_ylim(country_youtube_monthly_sum.max() * 0.0, country_youtube_monthly_sum.max() * 1.1)  # Set the limits for the y-axis, 
    ###
    # #여기 바꿔가면서 봐야함
    ###
    ax1.tick_params(axis='y', labelcolor='tab:red')  # Set the tick parameters for the y-axis

    # Create a second y-axis for the second graph
    ax2 = ax1.twinx()  
    ax2.plot(country_album_df['date'], country_album_df['export'], color = 'tab:blue', marker = '^', linestyle = '-', label = "Album Sales Data Points")  # 'g-' is for green solid line
    ax2.set_ylabel('Monthly Album sales data (1000 USD)', color='tab:blue')  # Set the label for the y-axis
    ax2.set_ylim(0, country_album_df['export'].max() * 1.1)  # Set the limits for the y-axis
    ax2.tick_params(axis='y', labelcolor='tab:blue')  # Set the tick parameters for the y-axis

    # Show the plot
    plt.title('Monthly YouTube Views and Album Sales of ' + country + ", from " + start + " to " + end)
    plt.legend()
    plt.show()

# %%
#show_monthly_youtube_graph('', '2021-05-01', '2023-10-31')
show_monthly_youtube_graph('Japan', '2022-01-01', '2022-12-31')

# %%
"""
현재 겪고 있는 문제들!
1. 관세청 통관 데이터는 월별이 한계라서 데이터가 너무 sparse하다.
2. 유튜브 조회수의 surge와 앨범 판매량의 surge 사이의 시간 차이 때문에 둘 사이의 상관관계를 찾기가 어렵다.
3. 유튜브 조회수의 surge와 앨범 판매량의 surge가 같은 이유에서(예를 들면 빅네임의 신곡 발표 등) 일어나는 지 확신할 수 없다.
    3-1. 해결책으로 앨범 주요 뮤직비디오의 유튜브 공개와 앨범 발매 시기(각 국가별로 다를 수 있음)의 시간 차이를 조사할 것이다.
"""
# Out:
# '\n현재 겪고 있는 문제들!\n1. 관세청 통관 데이터는 월별이 한계라서 데이터가 너무 sparse하다.\n2. 유튜브 조회수의 surge와 앨범 판매량의 surge 사이의 시간 차이 때문에 둘 사이의 상관관계를 찾기가 어렵다.\n3. 유튜브 조회수의 surge와 앨범 판매량의 surge가 같은 이유에서(예를 들면 빅네임의 신곡 발표 등) 일어나는 지 확신할 수 없다.\n    3-1. 해결책으로 앨범 주요 뮤직비디오의 유튜브 공개와 앨범 발매 시기(각 국가별로 다를 수 있음)의 시간 차이를 조사할 것이다.\n'

# %%
show_monthly_youtube_graph('United States', '2021-05-01', '2023-10-31')
# Out:
# /var/folders/4t/lj2jkv114_3c4yz5pdp55ws80000gn/T/ipykernel_75745/2835768992.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_youtube_df['date'] = pd.to_datetime(country_youtube_df['date'], format='%Y%m%d')
# /var/folders/4t/lj2jkv114_3c4yz5pdp55ws80000gn/T/ipykernel_75745/2835768992.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_album_df['date'] = pd.to_datetime(country_album_df['date'], format='%Y-%m-%d')

# %%
show_monthly_youtube_graph('Taiwan', '2021-05-01', '2023-10-31')
# Out:
# /var/folders/4t/lj2jkv114_3c4yz5pdp55ws80000gn/T/ipykernel_75745/4194548169.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_youtube_df['date'] = pd.to_datetime(country_youtube_df['date'], format='%Y%m%d')
# /var/folders/4t/lj2jkv114_3c4yz5pdp55ws80000gn/T/ipykernel_75745/4194548169.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_album_df['date'] = pd.to_datetime(country_album_df['date'], format='%Y-%m-%d')

# %%
def show_two_graph_and_regression(country, start, end):
    country_youtube_df = allcountries_views_df[(allcountries_views_df['country'] == country)]
    country_youtube_df['date'] = pd.to_datetime(country_youtube_df['date'], format='%Y%m%d')
    country_monthly_sum = country_youtube_df.groupby(pd.Grouper(key='date', freq='M')).sum()
    country_monthly_sum = country_monthly_sum[(country_monthly_sum.index >= start) & (country_monthly_sum.index <= end)]
    country_monthly_sum.index = country_monthly_sum.index.to_period('M').to_timestamp()
    country_youtube_monthly_sum = country_monthly_sum['inc']
    
    country_album_df = country_album_sales_df[country_album_sales_df['country'] == country]
    country_album_df['date'] = pd.to_datetime(country_album_df['date'], format='%Y-%m-%d')
    country_album_df = country_album_df[(country_album_df['date'] >= start) & (country_album_df['date'] <= end)]
    
    fig, ax1 = plt.subplots(figsize=(12, 8))  # Create the figure and the first axis

    # Plot the first graph
    ax1.plot(country_youtube_monthly_sum.index, country_youtube_monthly_sum.values, color = 'tab:red', marker = 'o', linestyle = '-', label = "YouTube Viewcount Data Points")  # 'r-' is for red solid line
    ax1.set_xlabel('Month')
    ax1.set_ylabel('Monthly YouTube views increment', color='tab:red')  # Set the label for the y-axis
    ax1.set_ylim(country_youtube_monthly_sum.max() * 0.5, country_youtube_monthly_sum.max() * 1.1)  # Set the limits for the y-axis, 
    ###
    # #여기 바꿔가면서 봐야함
    ###
    ax1.tick_params(axis='y', labelcolor='tab:red')  # Set the tick parameters for the y-axis

    # Create a second y-axis for the second graph
    ax2 = ax1.twinx()  
    ax2.plot(country_album_df['date'], country_album_df['export'], color = 'tab:blue', marker = '^', linestyle = '-', label = "Album Sales Data Points")  # 'g-' is for green solid line
    ax2.set_ylabel('Monthly Album sales data (1000 USD)', color='tab:blue')  # Set the label for the y-axis
    ax2.set_ylim(0, country_album_df['export'].max() * 1.1)  # Set the limits for the y-axis
    ax2.tick_params(axis='y', labelcolor='tab:blue')  # Set the tick parameters for the y-axis
    
    # Linearly fit the two data points and plot the regression line
    # Get the x and y values for the regression line
    x = country_youtube_monthly_sum.values
    y = country_album_df['export']
    # 

    # Get the coefficients of the regression line
    m, b = np.polyfit(x, y, 1)
    # Plot the regression line

    ax3 = ax2.twinx()
    ax3.plot(x, m*x + b, color = 'green', linestyle = '--', label = 'Regression Line')
    ax3.set_ylabel('Regression Line', color='green')
    ax3.tick_params(axis='y', labelcolor='green')
    # put the value of proximity of the regression line to the data points in the plot
    plt.text(x[-1], m*x[-1] + b, 'R^2 = ' + str(np.corrcoef(x, y)[0, 1]**2))

    # Show the plot
    plt.title('Monthly YouTube Views and Album Sales of ' + country + ", from " + start + " to " + end)
    plt.legend()
    plt.show()
    # return the correlation coefficient
    print(np.corrcoef(x, y)[0, 1]**2)

# %%
show_two_graph_and_regression('United States', '2021-05-01', '2023-10-31')
# Out:
# /var/folders/4t/lj2jkv114_3c4yz5pdp55ws80000gn/T/ipykernel_75745/3412939231.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_youtube_df['date'] = pd.to_datetime(country_youtube_df['date'], format='%Y%m%d')
# /var/folders/4t/lj2jkv114_3c4yz5pdp55ws80000gn/T/ipykernel_75745/3412939231.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_album_df['date'] = pd.to_datetime(country_album_df['date'], format='%Y-%m-%d')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/backend_bases.py:2158, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2155     # we do this instead of `self.figure.draw_without_rendering`
#    2156     # so that we can inject the orientation
#    2157     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2158         self.figure.draw(renderer)
#    2159 if bbox_inches:
#    2160     if bbox_inches == "tight":
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axis.py:1387, in Axis.draw(self, renderer, *args, **kwargs)
#    1384     return
#    1385 renderer.open_group(__name__, gid=self.get_gid())
# -> 1387 ticks_to_draw = self._update_ticks()
#    1388 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1390 for tick in ticks_to_draw:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axis.py:1275, in Axis._update_ticks(self)
#    1270 def _update_ticks(self):
#    1271     """
#    1272     Update ticks (position and labels) using the current data interval of
#    1273     the axes.  Return the list of ticks that will be drawn.
#    1274     """
# -> 1275     major_locs = self.get_majorticklocs()
#    1276     major_labels = self.major.formatter.format_ticks(major_locs)
#    1277     major_ticks = self.get_major_ticks(len(major_locs))
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axis.py:1495, in Axis.get_majorticklocs(self)
#    1493 def get_majorticklocs(self):
#    1494     """Return this Axis' major tick locations in data coordinates."""
# -> 1495     return self.major.locator()
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/dates.py:1373, in AutoDateLocator.__call__(self)
#    1371 def __call__(self):
#    1372     # docstring inherited
# -> 1373     dmin, dmax = self.viewlim_to_dt()
#    1374     locator = self.get_locator(dmin, dmax)
#    1375     return locator()
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/dates.py:1158, in DateLocator.viewlim_to_dt(self)
#    1156 if vmin > vmax:
#    1157     vmin, vmax = vmax, vmin
# -> 1158 return num2date(vmin, self.tz), num2date(vmax, self.tz)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/dates.py:543, in num2date(x, tz)
#     517 """
#     518 Convert Matplotlib dates to `~datetime.datetime` objects.
#     519
#    (...)
#     540 For details, see the module docstring.
#     541 """
#     542 tz = _get_tzinfo(tz)
# --> 543 return _from_ordinalf_np_vectorized(x, tz).tolist()
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:2372, in vectorize.__call__(self, *args, **kwargs)
#    2369     self._init_stage_2(*args, **kwargs)
#    2370     return self
# -> 2372 return self._call_as_normal(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:2365, in vectorize._call_as_normal(self, *args, **kwargs)
#    2362     vargs = [args[_i] for _i in inds]
#    2363     vargs.extend([kwargs[_n] for _n in names])
# -> 2365 return self._vectorize_call(func=func, args=vargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:2455, in vectorize._vectorize_call(self, func, args)
#    2452 # Convert args to object arrays first
#    2453 inputs = [asanyarray(a, dtype=object) for a in args]
# -> 2455 outputs = ufunc(*inputs)
#    2457 if ufunc.nout == 1:
#    2458     res = asanyarray(outputs, dtype=otypes[0])
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/dates.py:362, in _from_ordinalf(x, tz)
#     359 dt = (np.datetime64(get_epoch()) +
#     360       np.timedelta64(int(np.round(x * MUSECONDS_PER_DAY)), 'us'))
#     361 if dt < np.datetime64('0001-01-01') or dt >= np.datetime64('10000-01-01'):
# --> 362     raise ValueError(f'Date ordinal {x} converts to {dt} (using '
#     363                      f'epoch {get_epoch()}), but Matplotlib dates must be '
#     364                       'between year 0001 and 9999.')
#     365 # convert from datetime64 to datetime:
#     366 dt = dt.tolist()
#
# ValueError: Date ordinal -15788754.100000001 converts to -41259-11-10T21:35:59.999744 (using epoch 1970-01-01T00:00:00), but Matplotlib dates must be between year 0001 and 9999.
